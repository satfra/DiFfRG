# %%
pip install https://github.com/satfra/DiFfRG/raw/refs/heads/main/python/dist/DiFfRG-1.0.0-py3-none-any.whl
# Out:
# Collecting diffrg==1.0.0
#   Using cached https://github.com/satfra/DiFfRG/raw/refs/heads/main/python/dist/DiFfRG-1.0.0-py3-none-any.whl (10 kB)
# Collecting numpy (from diffrg==1.0.0)
#   Downloading numpy-2.3.5-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Collecting scipy (from diffrg==1.0.0)
#   Downloading scipy-1.16.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (62 kB)
# Collecting matplotlib (from diffrg==1.0.0)
#   Downloading matplotlib-3.10.7-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting adaptive[notebook] (from diffrg==1.0.0)
#   Using cached adaptive-1.4.1-py3-none-any.whl.metadata (12 kB)
# Collecting pandas (from diffrg==1.0.0)
#   Downloading pandas-2.3.3-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting seaborn (from diffrg==1.0.0)
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting jupyter_bokeh (from diffrg==1.0.0)
#   Using cached jupyter_bokeh-4.0.5-py3-none-any.whl.metadata (7.1 kB)
# Collecting vtk (from diffrg==1.0.0)
#   Downloading vtk-9.5.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.6 kB)
# Collecting sortedcollections>=1.1 (from adaptive[notebook]->diffrg==1.0.0)
#   Using cached sortedcollections-2.1.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting sortedcontainers>=2.0 (from adaptive[notebook]->diffrg==1.0.0)
#   Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl.metadata (10 kB)
# Collecting cloudpickle (from adaptive[notebook]->diffrg==1.0.0)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Collecting loky>=2.9 (from adaptive[notebook]->diffrg==1.0.0)
#   Using cached loky-3.5.6-py3-none-any.whl.metadata (8.4 kB)
# Collecting versioningit (from adaptive[notebook]->diffrg==1.0.0)
#   Using cached versioningit-3.3.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: ipython in ./.venv/lib/python3.13/site-packages (from adaptive[notebook]->diffrg==1.0.0) (9.7.0)
# Requirement already satisfied: ipykernel>=4.8.0 in ./.venv/lib/python3.13/site-packages (from adaptive[notebook]->diffrg==1.0.0) (7.1.0)
# Requirement already satisfied: jupyter-client>=5.2.2 in ./.venv/lib/python3.13/site-packages (from adaptive[notebook]->diffrg==1.0.0) (8.6.3)
# Collecting holoviews>=1.9.1 (from adaptive[notebook]->diffrg==1.0.0)
#   Downloading holoviews-1.22.0-py3-none-any.whl.metadata (10 kB)
# Collecting ipywidgets (from adaptive[notebook]->diffrg==1.0.0)
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting bokeh (from adaptive[notebook]->diffrg==1.0.0)
#   Downloading bokeh-3.8.1-py3-none-any.whl.metadata (10 kB)
# Collecting plotly (from adaptive[notebook]->diffrg==1.0.0)
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Collecting colorcet (from holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting narwhals>=2 (from holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Downloading narwhals-2.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: packaging in ./.venv/lib/python3.13/site-packages (from holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0) (25.0)
# Collecting panel>=1.0 (from holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Downloading panel-1.8.3-py3-none-any.whl.metadata (15 kB)
# Collecting param<3.0,>=2.0 (from holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Downloading param-2.3.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0) (2.9.0.post0)
# Collecting pyviz-comms>=2.1 (from holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached pyviz_comms-3.0.6-py3-none-any.whl.metadata (7.7 kB)
# Collecting Jinja2>=2.9 (from bokeh->adaptive[notebook]->diffrg==1.0.0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting contourpy>=1.2 (from bokeh->adaptive[notebook]->diffrg==1.0.0)
#   Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting pillow>=7.1.0 (from bokeh->adaptive[notebook]->diffrg==1.0.0)
#   Downloading pillow-12.0.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting PyYAML>=3.10 (from bokeh->adaptive[notebook]->diffrg==1.0.0)
#   Using cached pyyaml-6.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Requirement already satisfied: tornado>=6.2 in ./.venv/lib/python3.13/site-packages (from bokeh->adaptive[notebook]->diffrg==1.0.0) (6.5.2)
# Collecting xyzservices>=2021.09.1 (from bokeh->adaptive[notebook]->diffrg==1.0.0)
#   Downloading xyzservices-2025.11.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: comm>=0.1.1 in ./.venv/lib/python3.13/site-packages (from ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in ./.venv/lib/python3.13/site-packages (from ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (1.8.17)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in ./.venv/lib/python3.13/site-packages (from ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.venv/lib/python3.13/site-packages (from ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (0.2.1)
# Requirement already satisfied: nest-asyncio>=1.4 in ./.venv/lib/python3.13/site-packages (from ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in ./.venv/lib/python3.13/site-packages (from ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (7.1.3)
# Requirement already satisfied: pyzmq>=25 in ./.venv/lib/python3.13/site-packages (from ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (27.1.0)
# Requirement already satisfied: traitlets>=5.4.0 in ./.venv/lib/python3.13/site-packages (from ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in ./.venv/lib/python3.13/site-packages (from ipython->adaptive[notebook]->diffrg==1.0.0) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in ./.venv/lib/python3.13/site-packages (from ipython->adaptive[notebook]->diffrg==1.0.0) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in ./.venv/lib/python3.13/site-packages (from ipython->adaptive[notebook]->diffrg==1.0.0) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.venv/lib/python3.13/site-packages (from ipython->adaptive[notebook]->diffrg==1.0.0) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./.venv/lib/python3.13/site-packages (from ipython->adaptive[notebook]->diffrg==1.0.0) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in ./.venv/lib/python3.13/site-packages (from ipython->adaptive[notebook]->diffrg==1.0.0) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in ./.venv/lib/python3.13/site-packages (from ipython->adaptive[notebook]->diffrg==1.0.0) (0.6.3)
# Requirement already satisfied: wcwidth in ./.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->adaptive[notebook]->diffrg==1.0.0) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.venv/lib/python3.13/site-packages (from jedi>=0.18.1->ipython->adaptive[notebook]->diffrg==1.0.0) (0.8.5)
# Collecting MarkupSafe>=2.0 (from Jinja2>=2.9->bokeh->adaptive[notebook]->diffrg==1.0.0)
#   Using cached markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: platformdirs>=2.5 in ./.venv/lib/python3.13/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.8.0->adaptive[notebook]->diffrg==1.0.0) (4.5.0)
# Collecting pytz>=2020.1 (from pandas->diffrg==1.0.0)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->diffrg==1.0.0)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting bleach (from panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Downloading bleach-6.3.0-py3-none-any.whl.metadata (31 kB)
# Collecting linkify-it-py (from panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting markdown (from panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Collecting markdown-it-py (from panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached markdown_it_py-4.0.0-py3-none-any.whl.metadata (7.3 kB)
# Collecting mdit-py-plugins (from panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached mdit_py_plugins-0.5.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting requests (from panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm (from panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting typing-extensions (from panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: ptyprocess>=0.5 in ./.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython->adaptive[notebook]->diffrg==1.0.0) (0.7.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in ./.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython->adaptive[notebook]->diffrg==1.0.0) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in ./.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython->adaptive[notebook]->diffrg==1.0.0) (3.0.1)
# Requirement already satisfied: pure-eval in ./.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython->adaptive[notebook]->diffrg==1.0.0) (0.2.3)
# Collecting webencodings (from bleach->panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached webencodings-0.5.1-py2.py3-none-any.whl.metadata (2.1 kB)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->adaptive[notebook]->diffrg==1.0.0)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->adaptive[notebook]->diffrg==1.0.0)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Collecting mdurl~=0.1 (from markdown-it-py->panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting cycler>=0.10 (from matplotlib->diffrg==1.0.0)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->diffrg==1.0.0)
#   Downloading fonttools-4.60.1-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (112 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib->diffrg==1.0.0)
#   Using cached kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Collecting pyparsing>=3 (from matplotlib->diffrg==1.0.0)
#   Downloading pyparsing-3.2.5-py3-none-any.whl.metadata (5.0 kB)
# Collecting charset_normalizer<4,>=2 (from requests->panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached charset_normalizer-3.4.4-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests->panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests->panel>=1.0->holoviews>=1.9.1->adaptive[notebook]->diffrg==1.0.0)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Using cached adaptive-1.4.1-py3-none-any.whl (125 kB)
# Downloading holoviews-1.22.0-py3-none-any.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 12.5 MB/s  0:00:00 13.0 MB/s eta 0:00:01
# Downloading param-2.3.0-py3-none-any.whl (139 kB)
# Downloading bokeh-3.8.1-py3-none-any.whl (7.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 10.0 MB/s  0:00:000.7 MB/s eta 0:00:01:01
# Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached loky-3.5.6-py3-none-any.whl (56 kB)
# Using cached markupsafe-3.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (22 kB)
# Downloading narwhals-2.12.0-py3-none-any.whl (425 kB)
# Downloading numpy-2.3.5-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 11.6 MB/s  0:00:01 eta 0:00:010:00:01
# Downloading pandas-2.3.3-cp313-cp313-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 11.2 MB/s  0:00:01 12.3 MB/s eta 0:00:01
# Downloading panel-1.8.3-py3-none-any.whl (30.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.2/30.2 MB 12.4 MB/s  0:00:02 eta 0:00:010:01:01
# Downloading pillow-12.0.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 12.3 MB/s  0:00:002.7 MB/s eta 0:00:01:01
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached pyviz_comms-3.0.6-py3-none-any.whl (84 kB)
# Using cached pyyaml-6.0.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (801 kB)
# Using cached sortedcollections-2.1.0-py3-none-any.whl (9.5 kB)
# Using cached sortedcontainers-2.4.0-py2.py3-none-any.whl (29 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading xyzservices-2025.11.0-py3-none-any.whl (93 kB)
# Downloading bleach-6.3.0-py3-none-any.whl (164 kB)
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached colorcet-3.1.0-py3-none-any.whl (260 kB)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 12.1 MB/s  0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 12.0 MB/s  0:00:00
# Using cached jupyter_bokeh-4.0.5-py3-none-any.whl (148 kB)
# Using cached linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Using cached markdown-3.10-py3-none-any.whl (107 kB)
# Using cached markdown_it_py-4.0.0-py3-none-any.whl (87 kB)
# Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading matplotlib-3.10.7-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 12.5 MB/s  0:00:00 12.8 MB/s eta 0:00:01
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.60.1-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 9.9 MB/s  0:00:0012.8 MB/s eta 0:00:01
# Using cached kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Downloading pyparsing-3.2.5-py3-none-any.whl (113 kB)
# Using cached mdit_py_plugins-0.5.0-py3-none-any.whl (57 kB)
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 12.4 MB/s  0:00:00 12.7 MB/s eta 0:00:01
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading scipy-1.16.3-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 12.4 MB/s  0:00:02 eta 0:00:010:01:01
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Using cached uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Using cached versioningit-3.3.0-py3-none-any.whl (38 kB)
# Downloading vtk-9.5.2-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (112.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.3/112.3 MB 8.8 MB/s  0:00:12 eta 0:00:010:00:01
# Using cached webencodings-0.5.1-py2.py3-none-any.whl (11 kB)
# Installing collected packages: webencodings, sortedcontainers, pytz, xyzservices, widgetsnbextension, versioningit, urllib3, uc-micro-py, tzdata, typing-extensions, tqdm, sortedcollections, PyYAML, pyparsing, pillow, param, numpy, narwhals, mdurl, MarkupSafe, markdown, kiwisolver, jupyterlab_widgets, idna, fonttools, cycler, colorcet, cloudpickle, charset_normalizer, certifi, bleach, scipy, requests, pyviz-comms, plotly, pandas, markdown-it-py, loky, linkify-it-py, Jinja2, contourpy, mdit-py-plugins, matplotlib, ipywidgets, bokeh, adaptive, vtk, seaborn, panel, jupyter_bokeh, holoviews, diffrg
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52/52 [diffrg]m━ 50/52 [holoviews]el]]ingit]
# Successfully installed Jinja2-3.1.6 MarkupSafe-3.0.3 PyYAML-6.0.3 adaptive-1.4.1 bleach-6.3.0 bokeh-3.8.1 certifi-2025.11.12 charset_normalizer-3.4.4 cloudpickle-3.1.2 colorcet-3.1.0 contourpy-1.3.3 cycler-0.12.1 diffrg-1.0.0 fonttools-4.60.1 holoviews-1.22.0 idna-3.11 ipywidgets-8.1.8 jupyter_bokeh-4.0.5 jupyterlab_widgets-3.0.16 kiwisolver-1.4.9 linkify-it-py-2.0.3 loky-3.5.6 markdown-3.10 markdown-it-py-4.0.0 matplotlib-3.10.7 mdit-py-plugins-0.5.0 mdurl-0.1.2 narwhals-2.12.0 numpy-2.3.5 pandas-2.3.3 panel-1.8.3 param-2.3.0 pillow-12.0.0 plotly-6.5.0 pyparsing-3.2.5 pytz-2025.2 pyviz-comms-3.0.6 requests-2.32.5 scipy-1.16.3 seaborn-0.13.2 sortedcollections-2.1.0 sortedcontainers-2.4.0 tqdm-4.67.1 typing-extensions-4.15.0 tzdata-2025.2 uc-micro-py-1.0.3 urllib3-2.5.0 versioningit-3.3.0 vtk-9.5.2 webencodings-0.5.1 widgetsnbextension-4.0.15 xyzservices-2025.11.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import DiFfRG.file_io as io
import DiFfRG.plot as plt

import numpy as np
import math

from scipy.interpolate import make_interp_spline
from scipy.optimize import minimize

folder = "./build/"

# %%
kGeV, Zdat = io.read_k_csv(folder + "Zs.csv")
pGeV = Zdat[0]["pGeV"].to_numpy()
ZA = Zdat[0]["ZA"].to_numpy()

ZA_spl = make_interp_spline(pGeV, ZA, k=2)
better_p = np.exp(np.linspace(-4, 2, 256))
better_ZA = ZA_spl(better_p)

def chi_sq(opt):
    p_resc = opt[0]
    Z_resc = opt[1]
    p_max_lat = 0.955
    # find the maximum of the interpolated data
    p_max = better_p[np.argmin(better_ZA)] * p_resc

    return (p_max - p_max_lat)**2  + (better_ZA[np.argmin(better_ZA)] / Z_resc - 1/2.1)**2

p_resc, Z_resc = minimize(chi_sq, np.array([1, 0.7])).x

print("p_resc = ", p_resc)
print("Z_resc = ", Z_resc)
    
plt.plot_1D(
    [
        {
            "x": better_p*p_resc,
            "y": 1 / better_ZA * Z_resc,
            "scatter": False,
            "color" : plt.palette1[3],
            "label": "this work",
            "lw": 3
        },
    ],
    log_x=True,
    xlim = [1e-1, 10],
    ylim = [0, 3],
    legend_loc="upper left",
    xlabel=r"$p$ [GeV]",
    ylabel=r"$1/Z_A$",
    #file="YM_ZA_compare.pdf",
)
# Out:
# p_resc =  1.71977134649378
# Z_resc =  0.47795779903700675

# %%
kGeV, Zdat = io.read_k_csv(folder + "Zs.csv")

pGeV = Zdat[0]["pGeV"].to_numpy()
ZA = Zdat[0]["ZA"].to_numpy()
ZAbar = Zdat[0]["ZAbar"].to_numpy()
Zc = Zdat[0]["Zc"].to_numpy()

kGeV, alphas = io.read_k_csv(folder + "strong_couplings.csv")
alphaAcbc = alphas[0]["alphaAcbc"].to_numpy()
alphaA3 = alphas[0]["alphaA3"].to_numpy()
alphaA4 = alphas[0]["alphaA4"].to_numpy()

pGeV = pGeV * p_resc

# find the value of p where ZA is smallest, using a spline interpolation
spl = make_interp_spline(pGeV, ZA, k=3)
better_p = np.linspace(pGeV.min(), pGeV.max(), 8000)
better_ZA = spl(better_p)
pMax = better_p[np.argmin(better_ZA)]
print("maximum at p = ", pMax)

# fit ZA with p^(-4 * kappa) using scipy curve_fit
from scipy.optimize import curve_fit

def fit_func(p, kappa, A):
    return A * p**(4 * kappa)

fit_max = 0.05

ZA_fit = 1 / ZA[pGeV < fit_max]
pGeV_fit = pGeV[pGeV < fit_max]
popt, pcov = curve_fit(fit_func, pGeV_fit, ZA_fit)
print("kappa = ", popt[0])

plt.plot_1D(
    [
        {
            "x": better_p,
            "y": 1 / better_ZA,
            "lw": 3,
            "color" : plt.palette1[3],
        },
        {
            "x": pGeV,
            "y": 1 / ZA,
            "scatter": True,
            "color" : "black",
            "size": 2,
        },
        # fit
        {
            "x": pGeV[pGeV < 1],
            "y": fit_func(pGeV[pGeV < 1], *popt),
            "label" : r"fit: $p^{-4 \kappa}$, " + rf"$\kappa = {popt[0]:.3f}$",
            "linestyle": "--",
            "color": plt.palette1[0],
        },
    ],
    log_x=True,
    log_y=True,
    grid=False,
    xlabel=r"$p$ [GeV]",
    ylabel=r"$1/Z_A$",
    ylim=[np.min(1 / ZA) * 0.99, 8.5],
    xlim=[1e-4, 40],
    legend_loc="lower right",
    #file="YM_ZA.pdf"
)

def fit_func(p, kappa, A):
    return A * p**(2 * kappa)

Zc_fit = Zc[pGeV < fit_max]
pGeV_fit = pGeV[pGeV < fit_max]
popt, pcov = curve_fit(fit_func, pGeV_fit, Zc_fit)
print("kappa = ", popt[0])

plt.plot_1D(
    [
        {
            "x": pGeV,
            "y": Zc,
            #"label" : r"$Z_c$",
            "lw": 3,
            "color": plt.palette1[3],
        },
        {
            "x": pGeV,
            "y": Zc,
            "scatter": True,
            "color" : "black",
            "size": 2,
        },
        # fit
        {
            "x": pGeV[pGeV < 1],
            "y": fit_func(pGeV[pGeV < 1], *popt),
            "label" : r"fit: $p^{2 \kappa}$, " + rf"$\kappa = {popt[0]:.3f}$",
            "linestyle": "--",
            "color": plt.palette1[0],
        },
    ],
    log_x=True,
    log_y=True,
    grid=False,
    ylim = [np.min(Zc)*0.99, 1.5],
    xlabel=r"$p$ [GeV]",
    ylabel=r"$Z_c$",
    legend_loc="lower right",
    #file="YM_Zc.pdf"
)
# Out:
# maximum at p =  0.9676642960772687
# kappa =  0.5718314730710373
# /tmp/ipykernel_209047/3009848373.py:26: RuntimeWarning: overflow encountered in power
#   return A * p**(4 * kappa)
# kappa =  0.5639658035395659

# %%
plt.plot_1D(
    [   
        {
            "x": pGeV,
            "y": alphaAcbc,
            "label" : r"$\alpha_{A\bar{c}c}$",
            "lw": 2,
        },
        {
            "x": pGeV,
            "y": alphaA3,
            "label" : r"$\alpha_{A3}$",
            "lw": 2,
        },
        {
            "x": pGeV,
            "y": alphaA4,
            "label" : r"$\alpha_{A4}$",
            "lw": 2,
        },
    ],
    log_x=True,
    log_y=True,
    grid=False,
    #ylim=[1e-5, 10],
    xlim=[2.01e-3, 40],
    ylim=[1e-4, 10],
    xlabel=r"$p$ [GeV]",
    legend_loc="lower right",
    #file="YM_alphas.pdf"
)

# %%
kGeV, alphas = io.read_k_csv(folder + "strong_couplings.csv")
ZAcbc = alphas[0]["ZAcbc"].to_numpy()
ZA3 = alphas[0]["ZA3"].to_numpy()
ZA4 = alphas[0]["ZA4"].to_numpy()

plt.plot_1D(
    [   
        {
            "x": pGeV,
            "y": ZAcbc,
            "label" : r"$Z_{A\bar{c}c}$",
            "lw": 2,
        },
        {
            "x": pGeV,
            "y": ZA3,
            "label" : r"$Z_{A3}$",
            "lw": 2,
        },
        {
            "x": pGeV,
            "y": ZA4,
            "label" : r"$Z_{A4}$",
            "lw": 2,
        },
    ],
    log_x=True,
    log_y=True,
    grid=False,
    #ylim=[1e-5, 10],
    xlim=[2.01e-3, 40],
    xlabel=r"$p$ [GeV]",
    legend_loc="lower right",
    #file="YM_alphas.pdf"
)
